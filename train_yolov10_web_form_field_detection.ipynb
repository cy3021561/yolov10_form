# %%
# !nvidia-smi
# Out:
# Tue Sep 24 22:46:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# !pip install -q supervision albumentations==1.4
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 13.6 MB/s eta 0:00:00

# %% [markdown]
# ## Dataset

# %%
import os

HOME = os.getcwd()

# !mkdir -p {HOME}/weights
# !wget -P {HOME}/weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10x.pt

# dataset_config_pth = f"{HOME}/drive/MyDrive/aug_dataset_1/data.yaml"
# pretrained_weight = f"{HOME}/weights/yolov10x.pt"

# %%
# %cd {HOME}
# %ls

# !yolo task=detect mode=train epochs=100 batch=4 plots=True augment=False imgsz=1024 \
hsv_h=0 hsv_s=0 hsv_v=0 translate=0 scale=0 fliplr=0 mosaic=0 erasing=0 crop_fraction=0 \
model={HOME}/weights/yolov10x.pt \
data={HOME}/drive/MyDrive/aug_dataset_1/data.yaml
# Out:
# /content
# drive/  runs/  sample_data/  weights/  yolov8n.pt
# ...

# %%
# Step 1: Mount your Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Define the source and destination paths
# Source files in Colab's filesystem
best_model_src = '/content/runs/detect/train3/weights/best.pt'
last_model_src = '/content/runs/detect/train3/weights/last.pt'

# Destination folder in your Google Drive
# Change 'MyDrive' to the folder where you want to save the models
best_model_dest = '/content/drive/MyDrive/YOLO_weights/best.pt'
last_model_dest = '/content/drive/MyDrive/YOLO_weights/last.pt'

# Step 3: Copy the files to Google Drive
import shutil
shutil.copy(best_model_src, best_model_dest)
shutil.copy(last_model_src, last_model_dest)

print("Models have been copied to your Google Drive!")
